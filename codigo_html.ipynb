# %%
html_code = """<!DOCTYPE html>

<html>
<head> 
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Lista de Tareas</title>
    <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons/font/bootstrap-icons.css" rel="stylesheet">
    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet">
    <style>
        .full-page {
            min-height: 100vh;
            display: flex;
            justify-content: center;
            align-items: center;
            background-color: #28a745;
            color: white;
        }
        .container-box {
            background: white;
            padding: 20px;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
            width: 100%;
            max-width: 500px;
            color: black;
        }
    </style>
</head>
<body>
    <div class="full-page">
        <div class="container-box text-center">
            <h1 class="mb-3">Lista de Tareas</h1>
            
            {% with messages = get_flashed_messages() %}
                {% if messages %}
                    <div class="alert alert-warning text-center">
                        <ul class="mb-0">
                            {% for message in messages %}
                                <li>{{ message }}</li>
                            {% endfor %}
                        </ul>
                    </div>
                {% endif %}
            {% endwith %}
            
            <form action="/add" method="POST">
                <div class="mb-3">
                    <label for="actividad" class="form-label">Actividad</label>
                    <input type="text" class="form-control" id="actividad" name="actividad" required>
                </div>
                <button type="submit" class="btn btn-primary w-100">Agregar <i class="bi bi-arrow-bar-down"></i></button>
            </form>
            
            <hr>
            
            <table class="table table-bordered text-center">
                <thead class="table-light">
                    <tr>
                        <th>ID</th>
                        <th>Nombre</th>
                        <th>Acción</th>
                    </tr>
                </thead>
                <tbody>
                    {% for actividad in actividades %}
                    <tr>
                        <td>{{ actividad[0] }}</td>
                        <td>
                            <form action="/update/{{ actividad[0] }}" method="POST" class="d-flex">
                                <input type="text" name="actividad" value="{{ actividad[1] }}" class="form-control me-2" required>
                                <button type="submit" class="btn btn-warning">
                                    <i class="bi bi-arrow-repeat"></i>
                                </button>
                            </form>
                        </td>
                        <td>
                            <a href="/delete/{{ actividad[0] }}" class="btn btn-danger">
                                <i class="bi bi-trash3-fill"></i>
                            </a>
                        </td>
                    </tr>
                    {% endfor %}
                </tbody>
            </table>
        </div>
    </div>
    
    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
</body>

</html>"""

# Guardamos el archivo con codificación UTF-8
with open("templates/indexBD2.html", "w", encoding="utf-8") as file:
    file.write(html_code)

print("Archivo indexBD2.html guardado correctamente en UTF-8.")
# Out:
# Archivo indexBD2.html guardado correctamente en UTF-8.
