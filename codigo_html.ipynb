# %%
html_code = """<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Pokémon Registro</title>
    <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" rel="stylesheet">
    <style>
        body {
            background-image: url('https://wallpapercave.com/uwp/uwp4464291.jpeg'); 
            background-size: cover;
            background-position: center;
            color: #fff;
        }

        .container {
            max-width: 800px;
            margin: 0 auto;
            padding: 30px;
            background-color: rgba(0, 0, 0, 0.6); /* Fondo semitransparente */
            border-radius: 10px;
        }

        h1 {
            text-align: center;
            margin-bottom: 30px;
        }

        .btn-custom {
            background-color: #ffcc00;
            color: #fff;
            font-weight: bold;
        }

        .table {
            background-color: rgba(0, 0, 0, 0.7);
            border-radius: 8px;
        }
        
        .table th, .table td {
        color:  #FFFFFF; /* Color claro para la letra (puedes cambiarlo a cualquier color que desees) */
        }

        .form-control {
            border-radius: 8px;
            padding: 10px;
        }

        .flash-message {
            margin-top: 20px;
        }
    </style>
</head>
<body>
    <div class="container">
        <h1>Registro de Pokémones</h1>

        <!-- Flash messages -->
        {% with messages = get_flashed_messages() %}
            {% if messages %}
                <div class="alert alert-warning flash-message">
                    {% for message in messages %}
                        <p>{{ message }}</p>
                    {% endfor %}
                </div>
            {% endif %}
        {% endwith %}

        <!-- Formulario para agregar Pokémon -->
        <form method="POST" action="/add">
            <div class="form-group">
                <label for="nombre">Nombre:</label>
                <input type="text" class="form-control" id="nombre" name="nombre" required placeholder="Nombre del Pokémon">
            </div>
            <div class="form-group">
                <label for="tipo">Tipo:</label>
                <input type="text" class="form-control" id="tipo" name="tipo" required placeholder="Tipo de Pokémon">
            </div>
            <div class="form-group">
                <label for="nivel">Nivel:</label>
                <input type="number" class="form-control" id="nivel" name="nivel" min="1" max="20" required placeholder="Nivel (1-20)">
            </div>
            <button type="submit" class="btn btn-custom btn-block">Agregar Pokémon</button>
        </form>

        <!-- Pokémones registrados -->
        <h2 class="text-center my-5">Pokémones Registrados</h2>
        <table class="table table-striped">
            <thead>
                <tr>
                    <th>Nombre</th>
                    <th>Tipo</th>
                    <th>Nivel</th>
                    <th>Acciones</th>
                </tr>
            </thead>
            <tbody>
                {% for poke in prueba %}
                    <tr>
                        <td>{{ poke[1] }}</td>
                        <td>{{ poke[2] }}</td>
                        <td>{{ poke[3] }}</td>
                        <td>
                            <!-- Botón de abrir el modal de actualización -->
                            <button type="button" class="btn btn-warning btn-sm" data-toggle="modal" data-target="#updateModal{{ poke[0] }}">
                                Actualizar
                            </button>
                            <!-- Modal de actualización -->
                            <div class="modal fade" id="updateModal{{ poke[0] }}" tabindex="-1" role="dialog" aria-labelledby="updateModalLabel" aria-hidden="true">
                                <div class="modal-dialog" role="document">
                                    <div class="modal-content">
                                        <div class="modal-header">
                                            <h5 class="modal-title" id="updateModalLabel">Actualizar Pokémon</h5>
                                            <button type="button" class="close" data-dismiss="modal" aria-label="Cerrar">
                                                <span aria-hidden="true">&times;</span>
                                            </button>
                                        </div>
                                        <div class="modal-body">
                                            <form method="POST" action="/update/{{ poke[0] }}">
                                                <div class="form-group">
                                                    <label for="nombre">Nombre:</label>
                                                    <input type="text" class="form-control" name="nombre" value="{{ poke[1] }}" required>
                                                </div>
                                                <div class="form-group">
                                                    <label for="tipo">Tipo:</label>
                                                    <input type="text" class="form-control" name="tipo" value="{{ poke[2] }}" required>
                                                </div>
                                                <div class="form-group">
                                                    <label for="nivel">Nivel:</label>
                                                    <input type="number" class="form-control" name="nivel" value="{{ poke[3] }}" min="21" max="100" required placeholder="Nivel (21-100)">
                                                </div>
                                                <button type="submit" class="btn btn-warning btn-block">Actualizar</button>
                                            </form>
                                        </div>
                                    </div>
                                </div>
                            </div>

                            <!-- Botón de eliminar -->
                            <a href="/delete/{{ poke[0] }}" class="btn btn-danger btn-sm ml-2">Eliminar</a>
                        </td>
                    </tr>
                {% endfor %}
            </tbody>
        </table>
    </div>

    
    <script src="https://code.jquery.com/jquery-3.5.1.slim.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.0/dist/umd/popper.min.js"></script>
    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
</body>
</html>"""

# Guardamos el archivo con codificación UTF-8
with open("templates/indexBD3.html", "w", encoding="utf-8") as file:
    file.write(html_code)

print("Archivo indexBD3.html guardado correctamente en UTF-8.")
# Out:
# Archivo indexBD3.html guardado correctamente en UTF-8.
